# %%
import deepdish as dd
import csv
import json
import numpy as np

# %%
embeddings_path = './embeddings/sBERT/services.h5'
embeddings = dd.io.load(embeddings_path)
# embeddings = np.asarray(embeddings)

with open('./data/services_nodes.json') as sn:
    serv_nodes = json.loads(sn.read())

# %%
# reformat indexes of node_nums
node_num_map = {}
node_idx_map = {}
for i, node_num in enumerate(serv_nodes):
    node_num_map[node_num] = i
    node_idx_map[i] = node_num

edges = []
# reindex edgelist
with open('./data/services_edgelist.csv') as edge_file:
    serv_edges_reader = csv.reader(edge_file)
    with open('./data/services_BANE_edgelist.csv', 'w') as new_edges:
        edge_writer = csv.writer(new_edges, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        
        i = 0
        for edge in serv_edges_reader:
            if i == 0:
                edge_writer.writerow(edge)
                i += 1
                continue
            else:
                src, dst = edge
                edge = (node_num_map[src], node_num_map[dst])
                if i <= 20:
                    print(edge)
                edge_writer.writerow(edge)
                edges.append(edge)
                i += 1
        adj_li = {}
        for i in range(len(serv_nodes)):
            adj_li[i] = []

        for n1,n2 in edges:
            adj_li[n1] = adj_li[n1] + [n2]
            adj_li[n2] = adj_li[n2] + [n1]
        
        no_neigh_nodes = []
        for n in adj_li:
            if adj_li[n] == []:
                node_name = serv_nodes[node_idx_map[n]]
                print("Node {} ({}) has no neighbors".format(n, node_name))
                no_neigh_nodes.append(n)
        
        # add self-edges to see if that fixes dimensionality problem
        for n_idx in no_neigh_nodes:
            edge = (n_idx, n_idx)
            edges.append(edge)
            edge_writer.writerow(edge)
# Out:
# (9884, 3531)
# (6495, 9972)
# (12014, 3323)
# (12032, 12032)
# (108, 5188)
# (7137, 1863)
# (988, 6782)
# (3350, 4845)
# (5063, 6027)
# (3276, 15476)
# (12092, 16249)
# (6145, 291)
# (9196, 8849)
# (9350, 2428)
# (14718, 13998)
# (4878, 15902)
# (6889, 16164)
# (10233, 4574)
# (1122, 1808)
# (5440, 16369)
# Node 146 ({'AGENCY_ID': 73, 'SERV_ID': 6718, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, depending on the general need of the community. Vaccines may range from measles (MMR), tetanus (Tdap), hepatitis A, hepatitis B, and seasonal flu shots. Recommended to check availability in advance; vaccines subject to change without notice.', 'SERV_SITES': '[{"Site_Id":92,"Name":"Elkhart County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Elkhart","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Mon 8am-5pm; Tues-Fri 8am-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': 'www.elkhartcountyhealth.org', 'SERV_EMAIL': '', 'SERV_PHONE_1': '574-523-2127', 'SERV_PHONE_1_NOTE': 'Community Health Nursing', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Adults, age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if applicable)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Varies by vaccine; call for details.', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 28343, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 73, 'serv_id': 6718, 'eligibility': ['adults, age 19 or older'], 'intake': [], 'docs': ['shot records (if applicable)']}) has no neighbors
# Node 450 ({'AGENCY_ID': 146, 'SERV_ID': 16654, 'name': 'Adult Immunizations', 'SERV_AKA': 'CERT, Community Emergency Response Team Training', 'description': 'Provides low-cost immunizations for adults who are uninsured (whose insurance does not cover the vaccination). Several locations are available in Allen County. Service is offered on a walk-in basis. Open service area.', 'SERV_SITES': '[{"Site_Id":292,"Name":"Super Shot"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"DE KALB","state":"IN"},{"scope":"county","county":"Adams","state":"IN"},{"scope":"county","county":"Allen","state":"IN"},{"scope":"county","county":"Huntington","state":"IN"},{"scope":"county","county":"Noble","state":"IN"},{"scope":"county","county":"Wells","state":"IN"},{"scope":"county","county":"Whitley","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.3100"}]', 'SERV_OP_HOURS': 'Telephone: Vary; Clinic: Monthly 1st and 2nd Mon 10am-1pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '260-424-7468', 'SERV_PHONE_1_NOTE': 'Super Shot Clinic', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Living with a person with chronic Hepatitis B (for Hep A or Hep B vaccines) regardless of insurance status', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Walk in; clients must complete an intake form. All forms may be downloaded from the website.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records for all past immunizations -- Medicaid card (if applicable)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': '$10 per shot (unless covered by Medicaid); service is NOT denied due to inability to pay', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 28647, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': ['CERT', ' Community Emergency Response Team Training'], 'ag_id': 146, 'serv_id': 16654, 'eligibility': ['living with a person with chronic hepatitis b (for hep a or hep b vaccines) regardless of insurance status'], 'intake': [], 'docs': ['shot records for all past immunizations', 'medicaid card (if applicable)']}) has no neighbors
# Node 1023 ({'AGENCY_ID': 341, 'SERV_ID': 15751, 'name': 'Adult/Adolescent Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally. Fees vary by vaccine.', 'SERV_SITES': '[{"Site_Id":673,"Name":"Huntington County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Huntington","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Office: Mon-Fri 8am-11:45am and 12:45pm-4:30pm -- Clinic: Tues and Thurs 8am-11am and 1pm-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '260-358-4831', 'SERV_PHONE_1_NOTE': 'x 1', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': '$8 admin fee -- Flu Vaccine: $32 (or free for eligible, uninsured youth through age 18) -- Other Vaccines: Fixed fees vary by vaccine ($8-$200 per vaccine)', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 29220, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 341, 'serv_id': 15751, 'eligibility': ['age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 1566 ({'AGENCY_ID': 594, 'SERV_ID': 5888, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap) and hepatitis B. Fees vary by vaccine.', 'SERV_SITES': '[{"Site_Id":1048,"Name":"Clay County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Clay","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Clinic: Mon and Wed 8:30am-11am and 1pm-3pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-448-9019', 'SERV_PHONE_1_NOTE': 'Clinic', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 19 and older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': '* State-issued photo ID* Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary by vaccine; call for information.No medical billing; clients must pay in full at time of service.', 'SERV_PAY_METHODS': '["Cash","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 29763, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 594, 'serv_id': 5888, 'eligibility': ['age 19 and older'], 'intake': [], 'docs': ['state-issued photo id', 'shot records (if available)']}) has no neighbors
# Node 2025 ({'AGENCY_ID': 816, 'SERV_ID': 10353, 'name': 'Health Clinic - Rushville', 'SERV_AKA': '', 'description': "Offers affordable primary health care for uninsured and underinsured people. Services include family practice, pediatrics, sexually transmitted disease screenings, women's health services, laboratory testing, immunizations, diabetes treatment, asthma treatment, and patient education.", 'SERV_SITES': '[{"Site_Id":1393,"Name":"Meridian Health Services - Rushville Family Health Services"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Rush","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"RP-1400.2500"},{"taxonomy_code":"LF-4900.2400"},{"taxonomy_code":"LF-7100.1700"},{"taxonomy_code":"LN-1500"},{"taxonomy_code":"LT-3400.1500"},{"taxonomy_code":"LF-4900.8000"},{"taxonomy_code":"LV-6800"},{"taxonomy_code":"LF-4900.1500-650"},{"taxonomy_code":"LF-7100.8000"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-5:30pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-932-3699', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Open', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'New patients: Photo ID -- Proof of income (if uninsured) -- Insurance card (if applicable)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary; sliding scale available for income-eligible clients', 'SERV_PAY_METHODS': '["Cash","Personal Check","Credit Card","Debit Card","Private Insurance","Medicaid","Medicare","Healthy Indiana Plan (HIP)","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 30222, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 816, 'serv_id': 10353, 'eligibility': [], 'intake': [], 'docs': ['new patients: photo id', 'proof of income (if uninsured)', 'insurance card (if applicable)']}) has no neighbors
# Node 2110 ({'AGENCY_ID': 827, 'SERV_ID': 7819, 'name': 'Medical Clinic', 'SERV_AKA': '', 'description': 'Provides a full-service health clinic that specializes in family health care. Services include minor injuries and illnesses, physical exams (including exams for school and employment), immunizations, lab work, wellness care, and treatment of acute and chronic health problems.', 'SERV_SITES': '[{"Site_Id":1459,"Name":"Daviess Community Hospital Medical Clinic"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Daviess","state":"IN"},{"scope":"county","county":"Greene","state":"IN"},{"scope":"county","county":"Knox","state":"IN"},{"scope":"county","county":"Martin","state":"IN"},{"scope":"county","county":"Pike","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LN-1500"},{"taxonomy_code":"LF-7100.8000"},{"taxonomy_code":"LF-7100.1700"},{"taxonomy_code":"LT-3400.1500"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-4:30pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-254-6696', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Open', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': '* Photo ID* Insurance card (if applicable)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary by service; sliding scale available for income-eligible clients', 'SERV_PAY_METHODS': '["Cash","Personal Check","Credit Card","Debit Card","Private Insurance","Medicaid","Medicare","Healthy Indiana Plan (HIP)"]', 'SERV_ALT_LANGS': '["Spanish"]', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 30307, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 827, 'serv_id': 7819, 'eligibility': [], 'intake': [], 'docs': ['photo id', 'insurance card (if applicable)']}) has no neighbors
# Node 2482 ({'AGENCY_ID': 995, 'SERV_ID': 8784, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B.', 'SERV_SITES': '[{"Site_Id":1710,"Name":"Greene County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Greene","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Mon-Wed 8:15am-3:15pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-384-4496', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fixed fees vary by vaccine ($50-$125 per vaccine)', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 30679, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 995, 'serv_id': 8784, 'eligibility': ['age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 2779 ({'AGENCY_ID': 1140, 'SERV_ID': 15125, 'name': 'Adult/Adolescent Immunizations', 'SERV_AKA': '', 'description': 'Offers adult vaccinations, including tetanus (Tdap), HPV, hepatitis A, and hepatitis B, and Shingles. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":1909,"Name":"Howard County Health Department - Public Health Nursing"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Howard","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.3100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon and Fri, by appointment only', 'SERV_CLOSED_TIMES': 'CLOSED state and federal holidays', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-456-2403', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or older -- Other Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Photo ID -- Shot records (if available) -- Insurance card (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Flu Vaccine: $15 -- Other Vaccines: Fixed fees vary by vaccine', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 30976, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1140, 'serv_id': 15125, 'eligibility': ['flu vaccine: age 6 months or older ', 'other vaccines: age 19 or older'], 'intake': [], 'docs': ['photo id', 'shot records (if available)', 'insurance card (if available)']}) has no neighbors
# Node 2837 ({'AGENCY_ID': 1164, 'SERV_ID': 6883, 'name': 'Adult/Adolescent Immunization Clinic', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations including tetanus (Tdap), hepatitis A and B,  meningitis, pneumococcal bacteria, rubella, and shingles. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":1953,"Name":"Boone County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Boone","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Vaccines: By appointment only -- Office: Mon-Fri 8am-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-482-3942', 'SERV_PHONE_1_NOTE': 'Nursing and Vital Records', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 11 or older -- With or without insurance', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Call for details.', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary by vaccine', 'SERV_PAY_METHODS': '["Cash","Personal Check","Credit Card","Debit Card","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 31034, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1164, 'serv_id': 6883, 'eligibility': ['age 11 or older ', 'with or without insurance'], 'intake': [], 'docs': []}) has no neighbors
# Node 2873 ({'AGENCY_ID': 1176, 'SERV_ID': 13599, 'name': 'Adult/Adolescent Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally. Fees vary by vaccine.', 'SERV_SITES': '[{"Site_Id":1970,"Name":"Fayette County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Fayette","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Monthly 1st, 2nd, and 4th Wed 9am-11:45am and 1pm-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-825-4013', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or older -- Other Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': False, 'SERV_INTAKE_PROC': 'Walk in.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Flu Vaccine: $25-$35 depending on dose (or free for eligible, uninsured youth through age 18) -- Other Vaccines: Fixed fees vary by vaccine', 'SERV_PAY_METHODS': '["Cash","Medicaid","Medicare","Healthy Indiana Plan (HIP)","Money Order","Personal Check","Credit Card","Debit Card"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 31070, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1176, 'serv_id': 13599, 'eligibility': ['flu vaccine: age 6 months or older ', 'other vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 2895 ({'AGENCY_ID': 1186, 'SERV_ID': 15177, 'name': 'Adult/Adolescent Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, hepatitis B, and the HPV vaccine. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":1983,"Name":"Benton County Health Department - Patient Care Services"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Benton","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-10am and 1pm-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-884-1728', 'SERV_PHONE_1_NOTE': 'x 1', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Walk in or call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Flu Vaccine: $15-$16 (No cost for eligible, uninsured youth through age 18) -- Other Vaccines: Fixed fees vary by vaccine', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 31092, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1186, 'serv_id': 15177, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 2936 ({'AGENCY_ID': 1200, 'SERV_ID': 12907, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap),  HPV, hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":1998,"Name":"Fountain-Warren County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Fountain","state":"IN"},{"scope":"county","county":"Warren","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Tues 1pm-4pm and Thurs 8am-noon', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-762-3035', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '877-339-9567', 'SERV_PHONE_2_NOTE': 'Voice-Toll-Free', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Flu Vaccine: $15 (or free for eligible, uninsured youth through age 18)Other Vaccines: Fixed fees vary by vaccine ($50-$125 per vaccine)', 'SERV_PAY_METHODS': '["Cash","Personal Check","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 31133, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1200, 'serv_id': 12907, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 3224 ({'AGENCY_ID': 1331, 'SERV_ID': 13228, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":2323,"Name":"Clinton County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Clinton","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon, Tues, Wed, and Fri 8am-4pm; Thurs 8am-noon', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-659-6385', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or older -- Other Vaccines: Age 19 and older', 'SERV_HAS_PRE_REQ': False, 'SERV_INTAKE_PROC': 'Walk in, or call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fixed fees vary by vaccine ($35-$185 per vaccine)', 'SERV_PAY_METHODS': '["Cash","Personal Check","Private Insurance","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': 'Note: This office only offers immunizations to those wanting to self-pay or bill private insurance. Immunizations for children with Medicaid are done at the Clinton County Immunization Clinic located at St. Vincent Hospital in Frankfort.', 'node_num': 31421, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1331, 'serv_id': 13228, 'eligibility': ['flu vaccine: age 6 months or older ', 'other vaccines: age 19 and older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 3924 ({'AGENCY_ID': 1692, 'SERV_ID': 18337, 'name': 'Worthington Clinic', 'SERV_AKA': '', 'description': 'Provides a full-service health clinic that specializes in family health care. Services include treatment for minor injuries and illnesses, physical exams (including exams for school and employment), immunizations, lab work, wellness care, and treatment of acute and chronic health problems. Referrals for other physicians or social services may be provided, when necessary.', 'SERV_SITES': '[{"Site_Id":2928,"Name":"Greene County Health Incorporation - Worthington Clinic"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Greene","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LF-7100.1700"},{"taxonomy_code":"LN-1500"},{"taxonomy_code":"LT-3400.1500"}]', 'SERV_OP_HOURS': 'Mon-Fri 7am-7pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-875-2000', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Open', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': '* Photo ID* Proof of insurance, if applicable', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary; sliding scale may be available for eligible patients', 'SERV_PAY_METHODS': '["Private Insurance","Medicaid","Medicare","Healthy Indiana Plan (HIP)"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 32121, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1692, 'serv_id': 18337, 'eligibility': [], 'intake': [], 'docs': ['photo id', 'proof of insurance, if applicable']}) has no neighbors
# Node 3955 ({'AGENCY_ID': 1702, 'SERV_ID': 24130, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A,  hepatitis B, and the HPV vaccine. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":2942,"Name":"Clark County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Clark","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.3100"},{"taxonomy_code":"LF-4900.2200"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8:30am-4:30pm', 'SERV_CLOSED_TIMES': 'CLOSED state and federal holidays', 'SERV_WEB_URL': 'www.clarkhealth.net', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-282-7521', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fees vary', 'SERV_PAY_METHODS': '["Cash","Personal Check","Credit Card","Debit Card","Medicaid","Private Insurance","Healthy Indiana Plan (HIP)","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 32152, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1702, 'serv_id': 24130, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 4154 ({'AGENCY_ID': 1809, 'SERV_ID': 20012, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":3108,"Name":"Harrison County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Harrison","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon and Wed 9am-5:30pm; Tues and Thurs 7:30am-4pm (by appointment only)', 'SERV_CLOSED_TIMES': 'CLOSED on most major holidays.', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-738-3237', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or older -- Other Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary by vaccine', 'SERV_PAY_METHODS': '["Cash","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 32351, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1809, 'serv_id': 20012, 'eligibility': ['flu vaccine: age 6 months or older ', 'other vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 4226 ({'AGENCY_ID': 1835, 'SERV_ID': 14734, 'name': 'Adolescent/Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), measles, mumps, and rubella (MMR), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":3141,"Name":"Hancock County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Hancock","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-4pm ; by appointment', 'SERV_CLOSED_TIMES': 'Closed on major holidays.', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '317-477-1125', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call for vaccine availability and appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary by vaccine; call for details', 'SERV_PAY_METHODS': '["Cash","Personal Check","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 32423, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1835, 'serv_id': 14734, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 4695 ({'AGENCY_ID': 1985, 'SERV_ID': 21442, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B, and others. Flu shots available seasonally. Offers blood profiles that provide information about your general state of health.', 'SERV_SITES': '[{"Site_Id":3420,"Name":"La Porte County Health Department - La Porte"},{"Site_Id":3421,"Name":"La Porte County Health Department -Michigan City"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"La Porte","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-4pm', 'SERV_CLOSED_TIMES': 'CLOSED state and federal holidays', 'SERV_WEB_URL': 'www.laportecounty.org', 'SERV_EMAIL': 'lphealth@laportecounty.org', 'SERV_PHONE_1': '219-326-6808', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 18 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': False, 'SERV_REQ_DOCS': 'Shot records (preferred)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fixed fees vary by vaccine', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 32892, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 1985, 'serv_id': 21442, 'eligibility': ['age 18 or older'], 'intake': [], 'docs': ['shot records (preferred)']}) has no neighbors
# Node 5010 ({'AGENCY_ID': 2106, 'SERV_ID': 13997, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap) and hepatitis B. Fees vary by vaccine. All services provided by appointment.', 'SERV_SITES': '[{"Site_Id":3648,"Name":"Marshall County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Marshall","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '574-935-8565', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fees vary by vaccine', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 33207, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 2106, 'serv_id': 13997, 'eligibility': ['vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 5645 ({'AGENCY_ID': 2317, 'SERV_ID': 9622, 'name': 'Public Health Nurse', 'SERV_AKA': 'B.A.B.E., BABE, Bed and Britches, Maternal and Child Health', 'description': 'Provides public health screenings and services, including childhood immunizations, some adult immunizations, tuberculosis (TB) screening and treatment, blood pressure screening, head lice screening, and general health counseling and referrals.', 'SERV_SITES': '[{"Site_Id":4120,"Name":"Marion County Public Health Department - Northwest District Health"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Marion","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LF-4900.1000"}]', 'SERV_OP_HOURS': 'Walk-ins: Mon 2pm-5:30pm; Tues 8am-11:30am; Wed-Fri noon-3:30pm -- Appointments: Tues 8am-11:30am; Fri noon-3:30pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '317-221-7500', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Varies by service; primarily serves Marion County', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Walk in during designated hours or call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Photo ID (for adult patients or for adult accompanying minor patients) -- Shot records (if available) -- Insurance/Medicaid information (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary with service', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '["Translation service available"]', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 33842, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': ['B.A.B.E.', ' BABE', ' Bed and Britches', ' Maternal and Child Health'], 'ag_id': 2317, 'serv_id': 9622, 'eligibility': ['primarily serves marion county'], 'intake': [], 'docs': ['photo id (for adult patients or for adult accompanying minor patients)', 'shot records (if available)', 'insurance/medicaid information (if available)']}) has no neighbors
# Node 5646 ({'AGENCY_ID': 2317, 'SERV_ID': 9623, 'name': 'Public Health Nurse', 'SERV_AKA': 'B.A.B.E., BABE, Bed and Britches, Maternal and Child Health', 'description': 'Provides public services, including childhood immunizations, some adult immunizations, tuberculosis (TB) screening and treatment, blood pressure screening, head lice screening, and general health counseling and referrals.', 'SERV_SITES': '[{"Site_Id":4134,"Name":"Marion County Public Health Department - South District Health"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Marion","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LF-4900.1000"}]', 'SERV_OP_HOURS': 'Appointments: Tues 8am-noon and 3pm-6pm; Thurs 8am-noon; Fri 8am-4pm -- Walk-Ins: Mon and Wed 8am-4pm;', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '317-221-5700', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Varies by service; primarily serves Marion County', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment. -- Walk in during designated hours.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Photo ID (for adult patients or for adult accompanying minor patients) -- Shot records (if available) --  Insurance/Medicaid information (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary with service', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '["Translation service available"]', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 33843, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': ['B.A.B.E.', ' BABE', ' Bed and Britches', ' Maternal and Child Health'], 'ag_id': 2317, 'serv_id': 9623, 'eligibility': ['primarily serves marion county'], 'intake': [], 'docs': ['photo id (for adult patients or for adult accompanying minor patients)', 'shot records (if available)', 'insurance/medicaid information (if available)']}) has no neighbors
# Node 5647 ({'AGENCY_ID': 2317, 'SERV_ID': 9624, 'name': 'Public Health Nurse', 'SERV_AKA': '', 'description': 'Provides public health screenings and services, including childhood immunizations, some adult immunizations, tuberculosis (TB) screening and treatment, blood pressure screening, head lice screening, and general health counseling and referrals.', 'SERV_SITES': '[{"Site_Id":4119,"Name":"Marion County Public Health Department - Northeast District Health"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Marion","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LF-4900.1000"}]', 'SERV_OP_HOURS': 'Same Day Appointments: Tues noon-4pm; Thurs 8am-4pm; --  Scheduled Appointments: Mon 8am-3:30pm; Wed 3-5:30pm; Fri 8am-11:30am', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '317-221-7300', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Varies by service; primarily serves Marion County', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Walk in during designated hours for same day appointments. -- Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Photo ID (for adult patients or for adult accompanying minor patients) -- Shot records (if available) -- Insurance/Medicaid information (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary with service', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '["Translation service available"]', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 33844, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 2317, 'serv_id': 9624, 'eligibility': ['primarily serves marion county'], 'intake': [], 'docs': ['photo id (for adult patients or for adult accompanying minor patients)', 'shot records (if available)', 'insurance/medicaid information (if available)']}) has no neighbors
# Node 6210 ({'AGENCY_ID': 2512, 'SERV_ID': 13667, 'name': 'Adult/Adolescent Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult and travel vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":4796,"Name":"Jay County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Jay","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Office: Mon-Fri 8:30am-4:30pm Immunization Clinic: Mon 12:30pm-6:30pm; Wed 9am-4:30pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '260-726-8080', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'AgeAge 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available) -- Insurance information (including Medicaid/Medicare, if applicable)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Flu Vaccine: $8 for children; $26 for adultsOther Vaccines: Fixed fees vary by vaccine ($45-$205 per vaccine)', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 34407, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 2512, 'serv_id': 13667, 'eligibility': ['ageage 19 or older'], 'intake': [], 'docs': ['shot records (if available)', 'insurance information (including medicaid/medicare, if applicable)']}) has no neighbors
# Node 6246 ({'AGENCY_ID': 2537, 'SERV_ID': 8878, 'name': 'Clinic - Countyline Center', 'SERV_AKA': '', 'description': "Provides a full-service, primary care health clinic that specializes in family practice regardless of income or insurance status. The clinic provides general and sports physical exams, immunizations, lab work, women's and pediatric care, family planning, wellness care, and treatment of acute and chronic health problems. Staff will assist with completion of insurance forms and accepts Medicare and Medicaid/Hoosier Healthwise. Discounted rates are available for uninsured, low-income clients.", 'SERV_SITES': '[{"Site_Id":4824,"Name":"Windrose Health Network - Countyline Center"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Johnson","state":"IN"},{"scope":"county","county":"Marion","state":"IN"},{"scope":"county","county":"Shelby","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LF-7100.8000"},{"taxonomy_code":"LF-7100.1700"},{"taxonomy_code":"LJ-2000"},{"taxonomy_code":"LV-6000"},{"taxonomy_code":"LN-1500"},{"taxonomy_code":"LT-3400.1500"}]', 'SERV_OP_HOURS': 'Mon and Wed-Fri 8am-5pm; Tues 8am-6:30pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '317-884-7820', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Open', 'SERV_HAS_PRE_REQ': False, 'SERV_INTAKE_PROC': 'Walk-ins welcome, or call for an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'If uninsured, bring proof of income (prior year tax returns, W-2s, or past three paycheck stubs or disability checks) for sliding scale consideration.', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Sliding scale available for low-income, uninsured patients ($20 minimum office visit fee)', 'SERV_PAY_METHODS': '["Cash","Personal Check","Credit Card","Debit Card","Private Insurance","Medicaid","Medicare","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 34443, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 2537, 'serv_id': 8878, 'eligibility': [], 'intake': [], 'docs': ['if uninsured, bring proof of income (prior year tax returns, w-2s, or past three paycheck stubs or disability checks) for sliding scale consideration.']}) has no neighbors
# Node 6247 ({'AGENCY_ID': 2537, 'SERV_ID': 8879, 'name': 'Clinic - Hope Center', 'SERV_AKA': '', 'description': "Provides a full-service, primary care health center that specializes in family practice regardless of income or insurance status. This center provides immunizations, lab work, prenatal, pediatric, and women's care, family planning, wellness care, and treatment of acute and chronic health problems. Physical and sports exams (such as for school or employment) are also available. Staff will assist with completion of insurance forms. Discounted rates are available for uninsured, low-income clients.", 'SERV_SITES': '[{"Site_Id":4825,"Name":"Windrose Health Network - Hope Center"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Bartholomew","state":"IN"},{"scope":"county","county":"Brown","state":"IN"},{"scope":"county","county":"Decatur","state":"IN"},{"scope":"county","county":"Jackson","state":"IN"},{"scope":"county","county":"Jennings","state":"IN"},{"scope":"county","county":"Johnson","state":"IN"},{"scope":"county","county":"Shelby","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LN-1500"},{"taxonomy_code":"LF-7100.1700"},{"taxonomy_code":"LF-7100.8000"},{"taxonomy_code":"LT-3400.1500"},{"taxonomy_code":"LV-6000"},{"taxonomy_code":"LJ-2000"}]', 'SERV_OP_HOURS': 'Mon 8am-7pm; Tues-Fri 8am-5pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-546-6000', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Open', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call for appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'If uninsured, bring proof of income (prior year tax returns, W-2s, or past three paycheck stubs or disability checks) for sliding scale consideration.', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Sliding scale available for low-income, uninsured patients ($20 minimum office visit fee)', 'SERV_PAY_METHODS': '["Cash","Personal Check","Credit Card","Debit Card","Private Insurance","Medicaid","Medicare","Healthy Indiana Plan (HIP)","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 34444, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 2537, 'serv_id': 8879, 'eligibility': [], 'intake': [], 'docs': ['if uninsured, bring proof of income (prior year tax returns, w-2s, or past three paycheck stubs or disability checks) for sliding scale consideration.']}) has no neighbors
# Node 6671 ({'AGENCY_ID': 2712, 'SERV_ID': 14926, 'name': 'Adult/Adolescent Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":5222,"Name":"Miami County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Miami","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon, Wed, and Fri 8am-12:30pm and 1:30pm-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '765-472-3901', 'SERV_PHONE_1_NOTE': 'Government Switchboard', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': '*Flu Vaccine: None*Other Vaccines: Fixed fees vary by vaccine ($25-$160 per vaccine)', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 34868, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 2712, 'serv_id': 14926, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# ...
# Node 13374 ({'AGENCY_ID': 5772, 'SERV_ID': 2712, 'name': 'Franciscan ExpressCare Clinic', 'SERV_AKA': 'Hammond Care Urgent Care Center, Hammond Clinic', 'description': 'Offers a walk-in clinic for minor injuries and common illnesses, immunizations, and physicals. Typically serves non chronic conditions, including allergic reactions, coughs, cuts, bites, sprains, strains, sore throats, stomach aches, and fevers.', 'SERV_SITES': '[{"Site_Id":11318,"Name":"Franciscan Physician Network St. John"},{"Site_Id":15997,"Name":"Franciscan Physician Network Hammond Clinic"},{"Site_Id":15998,"Name":"Franciscan Physician Network Crown Point"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Lake","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.1500"},{"taxonomy_code":"LN-1500"},{"taxonomy_code":"LF-7100.8000"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Vary by site', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': 'www.franciscanhealth.org/healthcare-facilities/franciscan-expresscare-munster-2214', 'SERV_EMAIL': '', 'SERV_PHONE_1': '219-365-5577', 'SERV_PHONE_1_NOTE': 'Hammond', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '219-365-7000', 'SERV_PHONE_3_NOTE': 'Saint John', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Open', 'SERV_HAS_PRE_REQ': False, 'SERV_INTAKE_PROC': 'Walk in.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'State-issued photo ID -- Insurance information, if applicable', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary by service', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 41571, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': ['Hammond Care Urgent Care Center', ' Hammond Clinic'], 'ag_id': 5772, 'serv_id': 2712, 'eligibility': [], 'intake': [], 'docs': ['state-issued photo id', 'insurance information, if applicable']}) has no neighbors
# Node 13786 ({'AGENCY_ID': 6009, 'SERV_ID': 17583, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally. Fees vary by vaccine; HPV and flu vaccines are available (free/at a discount) for eligible uninsured youth through age 18.', 'SERV_SITES': '[{"Site_Id":11789,"Name":"Lake County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Lake","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.3100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Thurs 9am-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '219-755-3658', 'SERV_PHONE_1_NOTE': 'Clinic', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or older -- Other Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fixed fees vary by vaccine (fees waived for eligible clients, due to inability to pay)', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 41983, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6009, 'serv_id': 17583, 'eligibility': ['flu vaccine: age 6 months or older ', 'other vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 13807 ({'AGENCY_ID': 6011, 'SERV_ID': 17599, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally. Fees vary by vaccine; HPV and flu vaccines are available (at a discount) for eligible uninsured youth through age 18.', 'SERV_SITES': '[{"Site_Id":11793,"Name":"Porter County Health Department - Portage"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Porter","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.3100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8:30am-4:30pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '219-759-8239', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 2 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fixed fees vary by vaccine ($10-$197 per vaccine)', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 42004, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6011, 'serv_id': 17599, 'eligibility': ['flu vaccine: age 2 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 14107 ({'AGENCY_ID': 6119, 'SERV_ID': 11114, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), Hepatitis A, and Hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":11989,"Name":"Brown County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Brown","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-988-2255', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Vary; call for current costs', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 42304, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6119, 'serv_id': 11114, 'eligibility': ['age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 14371 ({'AGENCY_ID': 6248, 'SERV_ID': 10790, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":12204,"Name":"Bartholomew County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Bartholomew","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-5pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-379-1555', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Living in Bartholomew County -- Flu Vaccine: Age 6 months or older -- Other Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fixed fees vary by vaccine; most insurances can be billed', 'SERV_PAY_METHODS': '["Cash","Money Order","Cashiers Check"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 42568, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6248, 'serv_id': 10790, 'eligibility': ['living in bartholomew county ', 'flu vaccine: age 6 months or older ', 'other vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 14669 ({'AGENCY_ID': 6322, 'SERV_ID': 10699, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers Hepatitis B vaccinations to adults.', 'SERV_SITES': '[{"Site_Id":12360,"Name":"Jennings County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Jennings","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Tues 9am-11am and 1pm-3pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-352-3024', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Walk in.', 'SERV_CLIENT_NEEDS_TO_BRING': False, 'SERV_REQ_DOCS': 'Nothing needed', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': '$50 per dose (series of three)', 'SERV_PAY_METHODS': '["Cash","Personal Check","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 42866, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6322, 'serv_id': 10699, 'eligibility': ['age 19 or older'], 'intake': [], 'docs': []}) has no neighbors
# Node 14693 ({'AGENCY_ID': 6326, 'SERV_ID': 16860, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited vaccinations, including tetanus (Tdap), hepatitis A, hepatitis B, pneumonia, and shingles. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":12364,"Name":"Jackson County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Jackson","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-4:30pm ET', 'SERV_CLOSED_TIMES': 'CLOSED all federal holidays', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-522-6667', 'SERV_PHONE_1_NOTE': 'Nursing Division', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Flu Vaccine: Fees vary for individuals 19 and older; none for eligible, uninsured youth through age 18Other Vaccines: Fixed fees vary by vaccine', 'SERV_PAY_METHODS': '["Medicaid","Private Insurance","Cash","Personal Check","Credit Card","Debit Card"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': 'Spanish available upon request.', 'node_num': 42890, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6326, 'serv_id': 16860, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 15158 ({'AGENCY_ID': 6548, 'SERV_ID': 14673, 'name': 'Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A, and hepatitis B. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":12757,"Name":"Orange County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Orange","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"}]', 'SERV_OP_HOURS': 'Mon-Fri 8am-noon and 1pm-4pm', 'SERV_CLOSED_TIMES': '', 'SERV_WEB_URL': '', 'SERV_EMAIL': '', 'SERV_PHONE_1': '812-723-7112', 'SERV_PHONE_1_NOTE': '', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Age 19 or older', 'SERV_HAS_PRE_REQ': '', 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': '', 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fees vary by immunization provided', 'SERV_PAY_METHODS': '', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 43355, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 6548, 'serv_id': 14673, 'eligibility': ['age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors
# Node 15711 ({'AGENCY_ID': 7006, 'SERV_ID': 24143, 'name': 'Adolescent/Adult Immunizations', 'SERV_AKA': '', 'description': 'Offers limited adult vaccinations, including tetanus (Tdap), hepatitis A,  hepatitis B, and the HPV vaccine. Flu shots are available seasonally.', 'SERV_SITES': '[{"Site_Id":13505,"Name":"Floyd County Health Department"}]', 'SERV_GEO_TAG': '[{"scope":"county","county":"Floyd","state":"IN"}]', 'SERV_TAXONOMY_CODES': '[{"taxonomy_code":"X_LT-3400.0100"},{"taxonomy_code":"LT-3400.3100"},{"taxonomy_code":"LF-4900.2200"},{"taxonomy_code":"LT-3400.2000"}]', 'SERV_OP_HOURS': 'Avaliable during location hours', 'SERV_CLOSED_TIMES': 'CLOSED state and federal holidays', 'SERV_WEB_URL': 'http://www.floydcountyhealth.org', 'SERV_EMAIL': 'cbass@floydcounty.in.gov', 'SERV_PHONE_1': '', 'SERV_PHONE_1_NOTE': '812-948-4726', 'SERV_PHONE_2': '', 'SERV_PHONE_2_NOTE': '', 'SERV_PHONE_3': '', 'SERV_PHONE_3_NOTE': '', 'SERV_FAX': '', 'SERV_ELIGIBLE_DESCR': 'Flu Vaccine: Age 6 months or olderOther Vaccines: Age 19 or older', 'SERV_HAS_PRE_REQ': True, 'SERV_INTAKE_PROC': 'Call to schedule an appointment.', 'SERV_CLIENT_NEEDS_TO_BRING': True, 'SERV_REQ_DOCS': 'Shot records (if available)', 'SERV_OPTS_BRING_LIST': '', 'SERV_HAS_FEE': True, 'SERV_FEE_STRUCT': 'Fees vary', 'SERV_PAY_METHODS': '["Private Insurance","Cash","Personal Check","Credit Card","Debit Card","Medicaid","Healthy Indiana Plan (HIP)","Money Order"]', 'SERV_ALT_LANGS': '', 'SERV_WAIT_PERIOD': '', 'SERV_CAP_AND_TYPE': '', 'SERV_HELPLINE_NOTES': '', 'node_num': 43908, 'facet': 'Service', 'type': 'S', 'codes': [], 'akas': '', 'ag_id': 7006, 'serv_id': 24143, 'eligibility': ['flu vaccine: age 6 months or olderother vaccines: age 19 or older'], 'intake': [], 'docs': ['shot records (if available)']}) has no neighbors

# %%
remake_feats = ''
while remake_feats not in ('Y', 'N'):
    remake_feats = input("Would you like to create a new embeddings file for BANE? [Y/N]: ").upper()
remake_feats = True if remake_feats == 'Y' else False

# see here: https://github.com/benedekrozemberczki/BANE#datasets
feat_type = ''
while remake_feats not in ('S', 'D'):
    remake_feats = input("Would you like to save as sparse or dense BANE feats? [S/D]: ").upper()
feat_type = 'sparse' if remake_feats == 'S' else 'dense'
    
if remake_feats:
    
    if feat_type == 'sparse':
        sparse_feats = {}
        for i, node_num in enumerate(serv_nodes):
            sparse_feats[node_num_map[node_num]] = list(map(lambda e: float(e), embeddings[i]))
        with open('./data/BANE_sparse_feats.json', 'w') as feat_json:
            sparse_feats = json.dumps(sparse_feats)
            json.dump(sparse_feats, feat_json)
    else:
        # reset index from above (i still in scope)
        i = 0
        head = ['Node ID'] + ["Dim{} Feat".format(i) for i in range(len(embeddings[i]))]
        head_size = len(head)
        print("Header of Length {}".format(head_size))
        with open('./data/BANE_dense_feats.csv', 'w') as embed_file:
            embed_writer = csv.writer(embed_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            embed_writer.writerow(head)
            lines = []
            for i, node_num in enumerate(serv_nodes):
                # TODO: fix that node_num is saved as str in service_nodes and int in service_edgelist
                line = [node_num_map[node_num]] + list(embeddings[i])
                if len(line) != head_size:
                    print("Line with node {} has wrong length of {}".format(node_num, len(line)))
                lines.append(line)
            sorted_lines = sorted(lines, key = lambda x: x[0])
#             print(sorted_lines[:5])
            print(len(sorted_lines))
            for line in sorted_lines:
                embed_writer.writerow(line)
# Out:
# Would you like to create a new embeddings file for BANE? [Y/N]:  y
# Would you like to save as sparse or dense BANE feats? [S/D]:  d
# Header of Length 769
# 16547

# %% [markdown]
# ## NOTE: Both Algorithms have issues when there are no nodes with no neighbors in the network
#
# To fix:
# 1. Add self-edges to the nodes with no neighbors (Currently implemented) (**unknown consequences**)
# 2. Remove nodes with no neighbors (probably most sane solution, but concerning long-term since it's unlikely new added services
# especially informal ones will be tagged with taxonomy codes)

# %%
# !python BANE/src/main.py --edge-path /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Research/code_and_data/data/services_BANE_edgelist.csv --feature-path /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Research/code_and_data/data/BANE_dense_feats.csv --output-path /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Research/code_and_data/embeddings/BANE/bane_dense_embeddings_out.bin --features dense --dimensions 512
# Out:
# +----------------------+-------------------------------------------------------+
# |        Alpha         |                         0.01                          |
# +======================+=======================================================+
# | Approximation rounds | 5                                                     |
# +----------------------+-------------------------------------------------------+
# | Binarization rounds  | 10                                                    |
# +----------------------+-------------------------------------------------------+
# | Dimensions           | 512                                                   |
# +----------------------+-------------------------------------------------------+
# | Edge path            | /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Rese |
# |                      | arch/code_and_data/data/services_BANE_edgelist.csv    |
# +----------------------+-------------------------------------------------------+
# | Feature path         | /home/asvnpr/Documents/ND_CSE/workspace/Care-         |
# |                      | Net_Research/code_and_data/data/BANE_dense_feats.csv  |
# +----------------------+-------------------------------------------------------+
# | Features             | dense                                                 |
# +----------------------+-------------------------------------------------------+
# | Gamma                | 0.700                                                 |
# +----------------------+-------------------------------------------------------+
# | Order                | 1                                                     |
# +----------------------+-------------------------------------------------------+
# | Output path          | /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Rese |
# |                      | arch/code_and_data/embeddings/BANE/bane_dense_embeddi |
# |                      | ngs_out.bin                                           |
# +----------------------+-------------------------------------------------------+
#
# Target matrix creation started.
#
# Using dense features
#
# Fitting BANE model.
# Base SVD fitting started.
# <class 'scipy.sparse.csr.csr_matrix'>
# SVD completed.
# Fitting binary model.
#
# Iteration:   0%|                                         | 0/10 [00:00<?, ?it/s]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:19<09:16, 139.17s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:53<07:11, 143.79s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [07:26<04:52, 146.46s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [09:44<02:24, 144.02s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [11:53<00:00, 142.69s/it]
# Iteration:  10%|███                           | 1/10 [11:54<1:47:06, 714.02s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:08<08:33, 128.36s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:23<06:30, 130.31s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:37<04:23, 131.63s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:46<02:10, 130.68s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:58<00:00, 131.76s/it]
# Iteration:  20%|██████                        | 2/10 [22:53<1:33:00, 697.62s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:09<08:39, 129.98s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:20<06:30, 130.13s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:34<04:22, 131.20s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:41<02:10, 130.13s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:48<00:00, 129.64s/it]
# Iteration:  30%|█████████                     | 3/10 [33:42<1:19:40, 682.93s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:08<08:35, 128.93s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:16<06:25, 128.41s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:24<04:16, 128.35s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:33<02:08, 128.59s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:41<00:00, 128.35s/it]
# Iteration:  40%|████████████                  | 4/10 [44:24<1:07:04, 670.75s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:07<08:31, 127.95s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:15<06:23, 127.97s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:26<04:17, 128.82s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:43<02:11, 131.18s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:57<00:00, 131.54s/it]
# Iteration:  50%|████████████████                | 5/10 [55:22<55:34, 666.97s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:08<08:34, 128.74s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:17<06:26, 128.68s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:35<04:22, 131.47s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:44<02:10, 130.87s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [11:00<00:00, 132.18s/it]
# Iteration:  60%|██████████████████            | 6/10 [1:06:23<44:21, 665.31s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:09<08:39, 129.88s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:18<06:28, 129.36s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:25<04:17, 128.92s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:33<02:08, 128.49s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:40<00:00, 128.17s/it]
# Iteration:  70%|█████████████████████         | 7/10 [1:17:05<32:54, 658.13s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:08<08:32, 128.04s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:16<06:24, 128.25s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:24<04:16, 128.16s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:33<02:08, 128.49s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:41<00:00, 128.34s/it]
# Iteration:  80%|████████████████████████      | 8/10 [1:27:47<21:46, 653.33s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:07<08:28, 127.10s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:14<06:21, 127.23s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:21<04:14, 127.21s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:29<02:07, 127.40s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:36<00:00, 127.30s/it]
# Iteration:  90%|███████████████████████████   | 9/10 [1:38:24<10:48, 648.42s/it]
# Inner approximation::   0%|                               | 0/5 [00:00<?, ?it/s]
# Inner approximation::  20%|████▍                 | 1/5 [02:07<08:28, 127.14s/it]
# Inner approximation::  40%|████████▊             | 2/5 [04:14<06:21, 127.09s/it]
# Inner approximation::  60%|█████████████▏        | 3/5 [06:21<04:14, 127.24s/it]
# Inner approximation::  80%|█████████████████▌    | 4/5 [08:28<02:06, 126.96s/it]
# Inner approximation:: 100%|██████████████████████| 5/5 [10:34<00:00, 126.92s/it]
# Iteration: 100%|█████████████████████████████| 10/10 [1:48:59<00:00, 653.94s/it]
#
#
# Model saved.

# %%
# !python TENE/src/main.py --edge-path /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Research/code_and_data/data/services_BANE_edgelist.csv --feature-path /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Research/code_and_data/data/BANE_dense_feats.csv --output-path /home/asvnpr/Documents/ND_CSE/workspace/Care-Net_Research/code_and_data/embeddings/TENE/tene_dense_embeddings_out.bin --features dense --dimensions 768
# Out:
# +---------------+--------------------------------------------------------------+
# |   Parameter   |                            Value                             |
# +===============+==============================================================+
# | Alpha         | 1                                                            |
# +---------------+--------------------------------------------------------------+
# | Beta          | 1                                                            |
# +---------------+--------------------------------------------------------------+
# | Dimensions    | 768                                                          |
# +---------------+--------------------------------------------------------------+
# | Edge path     | /home/asvnpr/Documents/ND_CSE/workspace/Care-                |
# |               | Net_Research/code_and_data/data/services_BANE_edgelist.csv   |
# +---------------+--------------------------------------------------------------+
# | Feature path  | /home/asvnpr/Documents/ND_CSE/workspace/Care-                |
# |               | Net_Research/code_and_data/data/BANE_dense_feats.csv         |
/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  98%|████████████████████████████████████████ | 488/500 [39:08<00:57,  4.77s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  98%|████████████████████████████████████████ | 489/500 [39:12<00:52,  4.74s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  98%|████████████████████████████████████████▏| 490/500 [39:18<00:48,  4.84s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  98%|████████████████████████████████████████▎| 491/500 [39:23<00:44,  4.99s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  98%|████████████████████████████████████████▎| 492/500 [39:27<00:39,  4.88s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  99%|████████████████████████████████████████▍| 493/500 [39:35<00:38,  5.53s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  99%|████████████████████████████████████████▌| 494/500 [39:40<00:33,  5.62s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  99%|████████████████████████████████████████▌| 495/500 [39:45<00:26,  5.36s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  99%|████████████████████████████████████████▋| 496/500 [39:50<00:20,  5.18s/it](768, 16547)
# (16547, 768)
# (16547, 768)
#  99%|████████████████████████████████████████▊| 497/500 [39:59<00:18,  6.27s/it](768, 16547)
# (16547, 768)
# (16547, 768)
# 100%|████████████████████████████████████████▊| 498/500 [40:04<00:11,  5.86s/it](768, 16547)
# (16547, 768)
# (16547, 768)
# 100%|████████████████████████████████████████▉| 499/500 [40:08<00:05,  5.56s/it](768, 16547)
# (16547, 768)
# (16547, 768)
# 100%|█████████████████████████████████████████| 500/500 [40:13<00:00,  4.83s/it]
# Saving the embedding.

# %%
print("There are {} nodes in serv_nodes".format(len(serv_nodes)))
mx = 0
u_edges = set()
for n1,n2 in edges:
    if n1 > mx:
        mx = n1
    if n2 > mx:
        mx = n2
    u_edges.add(n1)
    u_edges.add(n2)
print("The largest node index in edgelist is {}".format(mx))
print("There are {} unique nodes in the network".format(len(u_edges)))
# Out:
# There are 16547 nodes in serv_nodes
# The largest node index in edgelist is 16546
# There are 16547 unique nodes in the network

# %%
print(len(list(set(list(serv_nodes.keys())))))
# Out:
# 16547

# %%
# Out:
# Node 146 has no neighbors
# Node 450 has no neighbors
# Node 1023 has no neighbors
# Node 1566 has no neighbors
# Node 2025 has no neighbors
# Node 2110 has no neighbors
# Node 2482 has no neighbors
# Node 2779 has no neighbors
# Node 2837 has no neighbors
# Node 2873 has no neighbors
# Node 2895 has no neighbors
# Node 2936 has no neighbors
# Node 3224 has no neighbors
# Node 3924 has no neighbors
# Node 3955 has no neighbors
# Node 4154 has no neighbors
# Node 4226 has no neighbors
# Node 4695 has no neighbors
# Node 5010 has no neighbors
# Node 5645 has no neighbors
# Node 5646 has no neighbors
# Node 5647 has no neighbors
# Node 6210 has no neighbors
# Node 6246 has no neighbors
# Node 6247 has no neighbors
# Node 6671 has no neighbors
# Node 8361 has no neighbors
# Node 8362 has no neighbors
# Node 8363 has no neighbors
# Node 8365 has no neighbors
# Node 8367 has no neighbors
# Node 8456 has no neighbors
# Node 8485 has no neighbors
# Node 8987 has no neighbors
# Node 9444 has no neighbors
# Node 10111 has no neighbors
# Node 10395 has no neighbors
# Node 11362 has no neighbors
# Node 11428 has no neighbors
# Node 12894 has no neighbors
# Node 12974 has no neighbors
# Node 13374 has no neighbors
# Node 13786 has no neighbors
# Node 13807 has no neighbors
# Node 14107 has no neighbors
# Node 14371 has no neighbors
# Node 14669 has no neighbors
# Node 14693 has no neighbors
# Node 15158 has no neighbors
# Node 15711 has no neighbors
